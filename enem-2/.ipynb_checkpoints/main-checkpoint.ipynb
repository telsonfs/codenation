# %%
import pandas as pd


from projeto_padrao.src.preprocessing import Preprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-efe5e0fb0ac4> in <module>
#       2
#       3
# ----> 4 from projeto_padrao.src.preprocessing import Preprocessing
#
# ImportError: cannot import name 'Preprocessing' from 'projeto_padrao.src.preprocessing' (unknown location)

# %%
train = pd.read_csv('projeto_padrao/data/train.csv')
test = pd.read_csv('projeto_padrao/data/test.csv')

# %%
train
# Out:
#        Unnamed: 0                              NU_INSCRICAO  NU_ANO  \
# 0               1  ed50e8aaa58e7a806c337585efee9ca41f1eb1ad    2016
# 1               2  2c3acac4b33ec2b195d77e7c04a2d75727fad723    2016
# 2               3  f4545f8ccb9ff5c8aad7d32951b3f251a26e6568    2016
# 3               4  3d6ec248fef899c414e77f82d5c6d2bffbeaf7fe    2016
# 4               5  bf896ac8d3ecadd6dba1dfbf50110afcbf5d3268    2016
# ...           ...                                       ...     ...
# 13725        4582  aadf671ef8c1c6efa42e69432093ab83c17a52ac    2016
# 13726        4583  461f7ef2753d9d5fa0b054930d6b0e0eec318e81    2016
# 13727        4584  5354503700ecf2388f68990435390b6e1ad454ee    2016
# 13728        4585  c7a9e94a42bd76b7978f13c013a61702e36cc42c    2016
# 13729        4586  0af8939c470a600b30bdaa80375ee0db848b0e35    2016
#
#        CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA  \
# 0                      4314902            Porto Alegre                43
# ...

# %%
test
# Out:
#                                   NU_INSCRICAO  CO_UF_RESIDENCIA  \
# 0     73ff9fcc02f0a99919906c942c2e1a1042cdcf98                41
# 1     71a95f9f1b91a82c65ad94abbdf9f54e6066f968                21
# 2     b38a03232f43b11c9d0788abaf060f7366053b6d                23
# 3     70b682d9a3636be23f6120fa9d6b164eb3c6002d                15
# 4     715494628a50142ce8cb17191cfe6d0f3cae0934                41
# ...                                        ...               ...
# 4571  dac0f22429c7f8e3931d0abaf5dfc8e5c772a48b                41
# 4572  a75fa8770257e7c9368d059fe53d9ef431f4bdef                35
# 4573  655fa6306720ff16e825903b5422a46608a77545                35
# 4574  1f4bc3e3d56212d500625bfe8ac78ccff4362293                52
# 4575  adf0d15b54317b6564ef56dad2b775bbb0ef50cc                33
#
#      SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_COR_RACA  TP_NACIONALIDADE  \
# 0                  PR        22       F            3                 1
# ...

# %%
preprocessing().data_info(train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-66222c858a75> in <module>
# ----> 1 preprocessing().data_info(train)
#
# TypeError: 'module' object is not callable

# %%
preprocessing.select_features(train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-fea7748bfc73> in <module>
# ----> 1 preprocessing.select_features(train)
#
# AttributeError: module 'projeto_padrao.src.preprocessing.preprocessing' has no attribute 'select_features'
